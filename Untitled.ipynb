# %% [markdown]
# ## Fundaentos de linguagem Python - do básico à aplicações de IA

# %% [markdown]
# ## Lista 1 de execícios

# %% [markdown]
# Exercício 1
#
# Escreva um programa que peça ao usuário para digitar seu nome, e em seguida, imprima uma mensafem de boas vindas com o nome fornecido.

# %%
nome = input("Digite seu nome:")
print(f"Olá, {nome}! Seja Bem-vindo(a)!")
# Out:
# Digite seu nome: carlos
# Olá, carlos! Seja Bem-vindo(a)!

# %% [markdown]
# ## Execício 2

# %% [markdown]
# Crie duas variáveis,numero 1 e número 2, e atribua a elas valores inteiros. Calcule a soma,subtração, multiplicação e divisão dessas variáveis e imprima os resultados.

# %%
numero1 = 10
numero2 = 5
print(f"Soma: {numero1 + numero2}")
print(f"Subtração: {numero1 - numero2}")
print(f"Multiplicação: {numero1 * numero2}")
print(f"Divisão: {numero1 / numero2}")
# Out:
# Soma: 15
# Subtração: 5
# Multiplicação: 50
# Divisão: 2.0

# %% [markdown]
# Exercício 3
# Qual é a principal diferença entre uma variável de escopo local e uma de escopo global?

# %% [markdown]
# Exercício 4

# %% [markdown]
# Crie uma variável chamada saldo com o valor 500.50 (float). Em seguida, crie uma variável saque com o valor 200.25 (float). Subtraia o saque do saldo e imprima o saldo final formatado para duas casas decimais.

# %%
# Solução
saldo = 500.50
saque = 200.25
saldo_final = saldo - saque
print(f"Seu saldo final é: R$ {saldo_final:.2f}")
# Out:
# Seu saldo final é: R$ 300.25

# %% [markdown]
# ## Execício 5
#
# Declare uma variável boolean chamada tem_carteira_de_motorista e atribua a ela o valor True. Imprima uma mensagem que diga "Pode dirigir" se a variável for Verdadeira e "Não pode dirigir" caso contrário.

# %%
# Solução
tem_carteira_de_motorista = True

if tem_carteira_de_motorista:
    print("Pode dirigir")
else:
    print("Não pode dirigir")
# Out:
# Pode dirigir

# %% [markdown]
# ## Exercício 6
#
# Crie duas variáveis:
#
# °idade_ana = 25
# °idade_beto = 30
#
# Use operadores de comparação para verificar se a idade de ana é menor que a de beto e imprima o resultado booleano.

# %%
# Solução
idade_ana = 25
idade_beto = 30 
print(idade_ana < idade_beto)
# Out:
# True

# %% [markdown]
# ## Execício 7
#
# Receba um número inteiro do usuário e use o operador de módulo (%) para verificar se o número é par ou ímpar. Imprima o resultado.

# %%
# Solução
numero = int(input("Digite um número inteiro:"))
if numero % 2 == 0:
    print(f" O número {numero} é PAR.")
else:
    print(f" o número {numero} é IMPAR.")
# Out:
# Digite um número inteiro: 10
#  O número 10 é PAR.

# %% [markdown]
# ## Execício 8
#
# Cire duas variáveis booleans:
#
# °chovendo = True
# °guarda_chuva = False
#
# Use operadores lógicos para verificar se uma pessoa vai se molhar(se está chovendo e ela não tem guarda-chuva).

# %%
# Solução
chovendo = True
guarda_chuva = False
vai_se_molhar = chovendo and not guarda_chuva
print(f"A pessoa vai se molhar? {vai_se_molhar}")
# Out:
# A pessoa vai se molhar? True

# %% [markdown]
# ## Exercicio 9
#
# Calcule a potência de 2 elevado a 10 e imprima o resultado.

# %%
# Solução
resultado = 2 ** 10
print(f"2 elevado a 10 é:{resultado}")
# Out:
# 2 elevado a 10 é:1024
